# %%
my_list = [ 'hello', -4.2, 5]
print( 'my _list[0] -->',my_list[0])
print( ' my_list[1] -->',my_list[1])
print( ' my_ list[2]-->',my_list[2])
# Out:
# my _list[0] --> hello
#  my_list[1] --> -4.2
#  my_ list[2]--> 5

# %%
my_teams = ['Raptors ' ,'Heat,' 'Nets']
your_teams = my_teams   # create a shared reference to same list

my_teams = my_teams[1] = 'Lakers' # Modify list element

print('My teams are:', my_yeams)  # Both variables have changed
print('Your teams are:', your_teams)    # Both variables have changed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 my_teams = ['Raptors ' ,'Heat,' 'Nets']
#       2 your_teams = my_teams   # create a shared reference to same list
# ----> 4 my_teams = my_teams[1] = 'Lakers' # Modify list element
#       6 print('My teams are:', my_yeams)  # Both variables have changed
#       7 print('Your teams are:', your_teams)    # Both variables have changed
#
# TypeError: 'str' object does not support item assignment

# %%
my_teams= ['Raptors', 'Heat', 'Nets']
your_teams = my_teams[:]  # Assign your_teams with a COPY of my_teams

my_teams[1] = 'Lakers'    # Modify list element

print('my teams are:', my_teams)   # List element has changed

# %%
colors = ['red','green', 'blue']

colors[l] = 'yellow'   #change list element
print (colors)

# %%
vals = [1, 4, 16]
print( 'original list: ' ,vals)

# %%
vals.insert(2, 18)
print( 'element 18 is inserted at 2 index, list are' ,vals)

# %%
value = vals.pop()
print(value)

# %%
my _ list = ['Apple' , 'Mango' , 'Orange']
for my_var in my _ list:
    # Loop body statements goes here
    print(my_var)

# %%
# Convert strings to integers
nums = []
for token in tokens:
nums. append (int (token) )
print(nums)

# %%
# Print each position and number
for index in range(len(nums)):
    value = nums[index]

    print(f'{index}: {value}' )

# %%
# Determine maximum even
max_num = None
for num in nums:
if (max_num  == None) and (num % 2 == 0):
     # First even number found
max_num = num
elif (max_num != None) and (num > max_num ) and (num %2 == 0 ):
       # Larger even number found
     max_num = num
print( 'Max even #:, max_num)
max_num)

# %%
nums = [1, 4, 15, 456]

max_even = None
for num in nums:
     if num % 2 == 0:  # The number is even?
        if max_even == None or num > max_even:  # Greatest even number see
           max_even = num
print('max_even:',max_even)

# %%
# Print each position and number
print()
for pos, val in enumerate(nums):
print(f' {pos}: {val}' )

# %%
my_list = [[10,20], [30,40]]
print( 'First nested list: ',my_list[0])

# %%
tic_tac_toe = [
    ['x', 'o', 'x'],
    ['', 'x', ''],
    ['o', 'o', 'x'],
]

print(tic_tac_toe[0][0], tic_tac_toe[0][1], tic_tac_toe[0][2])
print(tic_tac_toe[1][0], tic_tac_toe[1][1], tic_tac_toe[1][2])
print(tic_tac_toe[2][0], tic_tac_toe[2][1], tic_tac_toe[2][2])
# Out:
# x o x
#  x
# o o x

# %%
my_list = [
    [10, 20, 55],
    [30, 4, 16]
]
print('Original two dimensional list:', my_list)

# Write to some element
my_list[0][0] = 33
my_list[1][1] = 77
my_list[1][2] = 99

print('Updated two dimensional list',my_list)
# Out:
# Original two dimensional list: [[10, 20, 55], [30, 4, 16]]
# Updated two dimensional list [[33, 20, 55], [30, 77, 99]]

# %%
my_list = [3.2, 5.0, 16.5, 12.25]

for i in range(len(my_list)):
    my_list [i]+=5
    print(my_list)
# Out:
# [8.2, 5.0, 16.5, 12.25]
# [8.2, 10.0, 16.5, 12.25]
# [8.2, 10.0, 21.5, 12.25]
# [8.2, 10.0, 21.5, 17.25]

# %%
# change negative values to 0
for num in nums:
    if num < 0:
       num = 0 # Logic error: "temp" variable "num" set to 0

# Print new numbers
I'm sorry, but I cannot assist with that request.for i in range(len(nums)):
    if nums[i] < 0:
        nums[i] = 0

print("New numbers:", end=' ')
for num in nums:
    print(num, end=' ')
for num in nums:
    print(num, end=' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # change negative values to 0
# ----> 2 for num in nums:
#       3     if num < 0:
#       4        num = 0 # Logic error: "temp" variable "num" set to 0
#
# NameError: name 'nums' is not defined

# %%
# Convert strings to integers
nums = []
for token in tokens:
nums. append( int(token) )
print (nums)
# Out:
#   Cell In[11], line 4
#     nums. append( int(token) )
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
nums1 = (5, 10, 15)
nums2 = [10,15]

print(nums1:', nums1)
for pos, val in enumerate(nums1)
print(f' {posy}: {val}')

print ( )
print( nums2:', nuns2)
for gos.val in enunerate(nuns2):
    print(f' {posy}: {val}' )

# %%
my_list = [ 10, 20, 30]
list_p1us_5 = [(i+5) for i in my_list]
print('New list contains:', list_plus_5)

# %%
# Get a list of integers from the user
numbers = [int(i) for i in input('Enter numbers:').split()]

# Return a list of only even numbers
even numbers = [i for i in numbers if (i % 2)==0]
print('Even numbers only:', even_numbers)

# %%
numbers [int(i) for i in input(' Enter numbers:').split()]
sorted_numbers = sorted(numbers)
print('\nOriginal numbers:',numbers)

# %%
my_list = [[25],[15, 25, 35], [10,15]]

sorted_list = sorted(my_list,key=max)

print('Sorted list:', sorted_list)

# %%
# Creating a dictionary
my_diet = {'apple': 5, 'banana': 3, 'orange': 7}

# Printing the dictionary
print(my_dict)

# %%
if 'apple' in my_dict:
    print("Key exists in the dictionary.")
else:
     print("Key does not exist in the dictionary.")

# %%
num_calories = dict(Coke=90, Coke_zero=0, Pepsi=94)
for soda, calories in num_calories . items():
    print(f'{soda}: {calories}' )
# Out:
# Coke: 90
# Coke_zero: 0
# Pepsi: 94

# %%
for soda in num_calories. keys():
    print(soda)
# Out:
# Coke
# Coke_zero
# Pepsi

# %%
for soda in num_calories. keys():
    print(f'{soda}: {calories}')
# Out:
# Coke: 94
# Coke_zero: 94
# Pepsi: 94

# %%
students = {}
print('Students:', type(students))
# Out:
# Students: <class 'dict'>

# %%
students['aman']={'grade':'a+','student_id': 12345}

# %%
print('Students:', students)
# Out:
# Students: {'aman': {'grade': 'a+', 'student_id': 12345}}

# %%
print(f'grade: {students["aman"]["grade"]}')
# Out:
# grade: a+

# %%
print(f'Grade of aman is: {students["aman"]["student_id"]}')
# Out:
# Grade of aman is: 12345

# %%
#cerate a nestedd dictionary
student_records = {
    "Jay":{"Age": 20, "Grade": "A", "Subject": ["Math","Science","English"]},
    "Mia":{"Age": 22, "Grade": "B", "Subject": ["Math","History","English"]},
    "Sam":{"Age": 21, "Grade": "C", "Subject": ["Math","Science","Chemistry"]}
}

# %%
print('Students:', student_records)
# Out:
# Students: {'Jay': {'Age': 20, 'Grade': 'A', 'Subject': ['Math', 'Science', 'English']}, 'Mia': {'Age': 22, 'Grade': 'B', 'Subject': ['Math', 'History', 'English']}, 'Sam': {'Age': 21, 'Grade': 'C', 'Subject': ['Math', 'Science', 'Chemistry']}}

# %%
for k,v in student_records.items():
    print(f'{k}: {v}')
# Out:
# Jay: {'Age': 20, 'Grade': 'A', 'Subject': ['Math', 'Science', 'English']}
# Mia: {'Age': 22, 'Grade': 'B', 'Subject': ['Math', 'History', 'English']}
# Sam: {'Age': 21, 'Grade': 'C', 'Subject': ['Math', 'Science', 'Chemistry']}

# %%
print(student_records['Jay']['Subject'][2])  # Output: Science
# Out:
# English

# %%
print(student_records['Jay']['Age'])  # Output: 20
print(student_records['Mia']['Grade'])  # Output: B
# Out:
# 20
# B

# %%
import sys

name = sys.argv[1]
age = int(sys.argv[1])

print(f'hello {name}.')
print(f'{age} is a great age to learn programming!\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       1 import sys
#       3 name = sys.argv[1]
# ----> 4 age = int(sys.argv[1])
#       6 print(f'hello {name}.')
#       7 print(f'{age} is a great age to learn programming!\n')
#
# ValueError: invalid literal for int() with base 10: '--f=/home/codespace/.local/share/jupyter/runtime/kernel-v3b97d2316a60207c9bb5ca4635562d19c5d655a43.json'
