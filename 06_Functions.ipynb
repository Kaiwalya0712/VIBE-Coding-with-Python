# %%
def calc_pizza_area():
pi_val = 3.14159265

pizza_diameter = 12 .0
pizza _ radius = pizza _ diameter / 2. 0
pizza area = pi_val * pizza radius * pizza radius
return pizza_area
print( '12. 0 inch pizza is' , calc_pizza_area(),'square inches.')

# %%
def  computer_square(num_to_square):
return num_to_square * num_to_square

num_squared = compute_square(7)
print( '7 squared is ', num_squared)

# %%
def print_summary(oid,items,price):
print( 'Order' ,oid)
print( 'Items', items)
print( 'Total:', price)

# %%
# passing integer as an argument
# sum of two integers
m = add(2,5)
print(m)

# %%
# passing string as an argument
# concatenation Of two string
n = add('Anup ' ,'Kelkar')
print(n)

# %%
feet_per_step = 3
steps_per_minute = 70.0
calories_per_ minute_ walking = 3.5

steps = int(input( 'Enter number Of steps walked:'.))

feet =steps * feet_per_step
print( ' Feet:', feet)

# %%
minutes = steps / steps_per_minute
calories = minutes * calories_per_ minute_ walking
print( 'Calories: ' ,calories)

# %%
pi_val = 3.14
pizza_diameter 1 = 12.0
circle _ radius _ 1 = pizza_diameter_1/2.0
circle_area_l = pi_val * circle radius _1 *circle_radius_l

pizza_diameter_2 = 14.0
circle _radius 2 = pizza_diameter _2 / 2 .0
circle_area_2 = pi_val * circle radius _2 *circle _radius_2

total_pizza_area = +circ1e_area_1 +circle_area_2

print('A 12 and 14 inch pizza has', end:' ')
print(f' {total_pizza_area:,.2f} ' , end='')
print( 'square inches combined.')

# %%
CM PER INCH = 2.54
INCHES_PER _FOOT = 12

def height_US_to_cm(feet, inches) :
" " "Converts height in feet/ inches to centimeters""
total inches = feet*1NCHES_PER_FOOT + inches
cm = total_inches * CM_PER_INCH
return cm

i feet = 6
i inches = 4
centimeters = height_US_to_cm(i_feet,i inches)
print( ' Centimeters : ' centimeters)

# %%
def compute_square(num_to_square):
return num_to_square * num_to_square

c2 = compute_square(7) + compute_square(9)
print('7 squared plus 9 squared is', c2)

# %%
import math

def calc_circular_base_area(radius):
return math. pi * radius * radius

def calc_cy1inder_volume(baseRadius, height):
return calc_circu1ar_base_area(baseRadius) * height

def calc_cy1inder_surface_area(baseRadius, height) :
return (2 * math.pi * baseRadius * height) + (2 * calc_circu1ar_base_area(baseRadius))
radius = float(input('Enter base radius:'))
height = float(input ('Enter height:'))

print( 'Cylinder volume: ' + f' {calc_cylinder_volume(radius,height):.3f}')
print( 'Cylinder surface area:' + f'{calc_cylinder_surface_area(radius,height):,3f}')

# %%
def steps_to_feet(num_steps) :
feet_per_step = 3
feet = = num_steps * feet_per_step
return feet

def steps_to_calories(num_steps):
pass
steps = int(input( 'Enter number of steps walked:'  ))

feet = steps_to feet(steps)
print( ' Feet:', feet)
calories= = steps_to_calories(steps)
print( 'Calories: ' ,calories)

# %% [markdown]
# ### Functions with branches/loops

# %%
def calc_ebay_fee(sell_price):
  

  p50 =  0.13 # for amount $50 and lower
  p50_to_1000 =0.05 # for $50.01-$1000
  p1000 = 0.02  # for $ 1000.01 and h igher
  fee = 0.50 # fee to List item

  if sell_price <= 50:
    fee =fee + (sell_price-50)
  elif sell_price <= 1000:
    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)
  else:
    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\
            + ((sell_price-1000)*p1000)
    return fee

selling_price = float(input('Enter item selling price (ex: 65.00):'))
print('eBay fee: $', calc_ebay_fee(selling_price))
# Out:
# eBay fee: $ None

# %%
def calc_ebay_fee(sell_price):
  

  p50 =  0.13 # for amount $50 and lower
  p50_to_1000 =0.05 # for $50.01-$1000
  p1000 = 0.02  # for $ 1000.01 and h igher
  fee = 0.50 # fee to List item

  if sell_price <= 50:
    fee =fee + (sell_price-50)
  elif sell_price <= 1000:
    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)
  else:
    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\
            + ((sell_price-1000)*p1000)
    return fee

selling_price = float(input('Enter item selling price (ex: 65.00):'))
print('eBay fee: $', calc_ebay_fee(selling_price))
# Out:
# eBay fee: $ 64.5

# %% [markdown]
# ### Functions are objects

# %%
def print_human_head():
    print('  ||||| ')
    print('  o   o')
    print('    > ')
    print('  ooooo')
    return

# %%
def print_monkey_head():
    print('  .-"-.  ')
    print(' _/.-.-.\\_')
    print('( ( o o ) )')
    print(' |/  "  \\| ')
    print('  \\ .-. / ')
    print('  /`"""`\\ ')
    return

# %%
def print_figure(face):
    face() # Print the face
    print('     | ')
    print('   --|--')
    print('  /  |  \\\\')
    print('@    |    @')
    print('     | ')
    print('    /\\\\\\')
    print('   @   @')
    return

# %%
choice = int(input('Enter "1" to draw monkey, "2" for human:'))

if choice ==1:
    print_figure (print_monkey_head)
elif choice == 2:
    print_figure (print_human_head)
# Out:
#   |||||
#   o   o
#     >
#   ooooo
#      |
#    --|--
#   /  |  \\
# @    |    @
#      |
#     /\\\
#    @   @

# %%
choice = int(input('Enter "1" to draw monkey, "2" for human:'))

if choice ==1:
    print_figure (print_monkey_head)
elif choice == 2:
    print_figure (print_human_head)
# Out:
#   .-"-.
#  _/.-.-.\_
# ( ( o o ) )
#  |/  "  \|
#   \ .-. /
#   /`"""`\
#      |
#    --|--
#   /  |  \\
# @    |    @
#      |
#     /\\\
#    @   @

# %%
centimeters_per_inch =  2.54
inches_per_foot = 12

def height_US_to_centimeters(feet, inches):
    """ Converts a height in feet/ inches to centimeters."""
    total_inches = (feet * inches_per_foot) + inches # Total inches
    centimeters = total_inches * centimeters_per_inch
    return centimeters

i_feet = int(input('Enter feet: '))
i_inches = int(input( ' Enter inches:'))

print( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))
# Out:
# Centimeters:  2184.4

# %%
employee_name = 'N/A'
def get_name():

    name = input( ' Enter employee name: ' )
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  N/A

# %%
employee_name = 'N/A'
def get_name():
    global employee_name
    name = input( 'Enter employee name:')
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  kaiwalya pande

# %% [markdown]
# ### Scope of variables and functions

# %%
daily_cals = 230 # Daily calories
soda_cals = 200

def drink_soda(cals_left):
    return cals_left - soda_cals
daily_cals = drink_soda(daily_cals)
print(daily_cals)
# Out:
# 30

# %%
def avg(a, b):
    tmp = (a+b)/2.0
    return tmp
a = 5
b = 10
tmp = a+b

print(f'Avg: {avg(a, b): f}' )
print(f' Sum: {tmp:f}')
# Out:
# Avg:  7.500000
#  Sum: 15.000000

# %%
def avg(a, b):
    tmp = (a+b)/2.0     # Creates tmp in Locat namespace
    return tmp
a = 5
b = 10
tmp = a + b # Creates tmp in global namespace

print(f'Avg: {avg(a,b):f}' )
print(f'Sum: {tmp:f}')
# Out:
# Avg: 7.500000
# Sum: 15.000000

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x76392f1d7a70>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_ii': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_iii': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i1': 'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i2': 'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i3': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i4': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  'calc_ebay_fee': <function __main__.calc_ebay_fee(sell_price)>,
#  'selling_price': 1500.0,
#  '_i5': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i6': "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#  'print_human_head': <function __main__.print_human_head()>,
#  '_i7': 'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#  'print_monkey_head': <function __main__.print_monkey_head()>,
#  '_i8': "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#  'print_figure': <function __main__.print_figure(face)>,
#  '_i9': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#  '_i10': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  'choice': 1,
#  '_i11': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  '_i12': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i13': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i14': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i15': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  'i_feet': 67,
#  'i_inches': 56,
#  '_i16': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  '_i17': "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i18': "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i19': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'kaiwalya pande',
#  'get_name': <function __main__.get_name()>,
#  '_i20': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i21': 'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 30,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i22': "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i23': "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i24': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'avg': <function __main__.avg(a, b)>,
#  'b': 10,
#  '_i25': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'a': 5,
#  'tmp': 15,
#  '_i26': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i27': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i28': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i29': 'globals()'}

# %%
my_var = 'thi is global'
def print_globals_var():
    print('inside function',my_var)
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()',
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()"],
#  '_oh': {29: {...}},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()',
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()"],
#  'Out': {29: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x76392f1d7a70>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#  '_ii': 'globals()',
#  '_iii': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i1': 'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i2': 'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i3': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i4': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  'calc_ebay_fee': <function __main__.calc_ebay_fee(sell_price)>,
#  'selling_price': 1500.0,
#  '_i5': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i6': "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#  'print_human_head': <function __main__.print_human_head()>,
#  '_i7': 'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#  'print_monkey_head': <function __main__.print_monkey_head()>,
#  '_i8': "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#  'print_figure': <function __main__.print_figure(face)>,
#  '_i9': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#  '_i10': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  'choice': 1,
#  '_i11': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  '_i12': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i13': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i14': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i15': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  'i_feet': 67,
#  'i_inches': 56,
#  '_i16': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  '_i17': "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i18': "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i19': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'kaiwalya pande',
#  'get_name': <function __main__.get_name()>,
#  '_i20': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i21': 'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 30,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i22': "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i23': "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i24': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'avg': <function __main__.avg(a, b)>,
#  'b': 10,
#  '_i25': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'a': 5,
#  'tmp': 15,
#  '_i26': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i27': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i28': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i29': 'globals()',
#  '_29': {...},
#  '_i30': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#  '_i31': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()",
#  'my_var': 'thi is global',
#  'print_globals_var': <function __main__.print_globals_var()>}

# %%
def print_local_var():
    my_var_local = 'this is a locals variable'
    print(locals())

print_local_var()
print('outside function')
locals()
# Out:
# {'my_var_local': 'this is a locals variable'}
# outside function
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()',
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()",
#   "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Locat namespace\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')",
#   "def print_local_var():\n    my_var_local = 'this is a locals variable'\n    print(locals())\n\nprint_local_var()\nprint('outside function')\nlocals()"],
#  '_oh': {29: {...}, 31: {...}},
#  '_dh': [PosixPath('/workspaces/VIBE-Coding-with-Python')],
#  'In': ['',
#   'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def calc_ebay_fee(sell_price):\n\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#   "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#   'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#   "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#   'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#   "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#   'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#   "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#   'globals()',
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#   "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()",
#   "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Locat namespace\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')",
#   "def print_local_var():\n    my_var_local = 'this is a locals variable'\n    print(locals())\n\nprint_local_var()\nprint('outside function')\nlocals()"],
#  'Out': {29: {...}, 31: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x76392f1d7a70>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x76391da9b890>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': {...},
#  '___': '',
#  '__vsc_ipynb_file__': '/workspaces/VIBE-Coding-with-Python/06_Functions.ipynb',
#  '_i': "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Locat namespace\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')",
#  '_ii': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()",
#  '_iii': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#  '_i1': 'def calc_ebay_fee(sell_price):\n" " "Returns the fees charged by ebay.com given the selling\nprice of fixed-price books, movies, music, or video games.\nfee is $0.50 to list plus 13% of selling price up to $50 .00,\n5% of amount from $50.01 to $1000.00, and\n2% for amount $1000.01 or more."""\n\np50 =  0.13 # for amount $50 and lower\np50_to_1000 =0.05 # for $50.01-$1000\np1000 = 0.02  # for $ 1000.01 and h igher\nfee = 0.50 # fee to List item\n\nif sell_price <= 50:\nfee =fee + (sell_price-50)\nelif sell_price <= 1000:\nfee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i2': 'def calc_ebay_fee(sell_price):\n  " " "Returns the fees charged by ebay.com given the selling\n  price of fixed-price books, movies, music, or video games.\n  fee is $0.50 to list plus 13% of selling price up to $50 .00,\n  5% of amount from $50.01 to $1000.00, and\n  2% for amount $1000.01 or more."""\n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input(\'Enter item selling price (ex: 65.00):\'))\nprint(\'eBay fee: $\', calc_ebay_fee(selling_price))',
#  '_i3': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\nelse:\n  fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i4': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  'calc_ebay_fee': <function __main__.calc_ebay_fee(sell_price)>,
#  'selling_price': 1500.0,
#  '_i5': "def calc_ebay_fee(sell_price):\n  \n\n  p50 =  0.13 # for amount $50 and lower\n  p50_to_1000 =0.05 # for $50.01-$1000\n  p1000 = 0.02  # for $ 1000.01 and h igher\n  fee = 0.50 # fee to List item\n\n  if sell_price <= 50:\n    fee =fee + (sell_price-50)\n  elif sell_price <= 1000:\n    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)\n  else:\n    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\\\n            + ((sell_price-1000)*p1000)\n    return fee\n\nselling_price = float(input('Enter item selling price (ex: 65.00):'))\nprint('eBay fee: $', calc_ebay_fee(selling_price))",
#  '_i6': "def print_human_head():\n    print('  ||||| ')\n    print('  o   o')\n    print('    > ')\n    print('  ooooo')\n    return",
#  'print_human_head': <function __main__.print_human_head()>,
#  '_i7': 'def print_monkey_head():\n    print(\'  .-"-.  \')\n    print(\' _/.-.-.\\\\_\')\n    print(\'( ( o o ) )\')\n    print(\' |/  "  \\\\| \')\n    print(\'  \\\\ .-. / \')\n    print(\'  /`"""`\\\\ \')\n    return',
#  'print_monkey_head': <function __main__.print_monkey_head()>,
#  '_i8': "def print_figure(face):\n    face() # Print the face\n    print('     | ')\n    print('   --|--')\n    print('  /  |  \\\\\\\\')\n    print('@    |    @')\n    print('     | ')\n    print('    /\\\\\\\\\\\\')\n    print('   @   @')\n    return",
#  'print_figure': <function __main__.print_figure(face)>,
#  '_i9': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print _ figure (print_monkey_head)\nelif choice == 2:\nprint _ figure (print_human_head)',
#  '_i10': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  'choice': 1,
#  '_i11': 'choice = int(input(\'Enter "1" to draw monkey, "2" for human:\'))\n\nif choice ==1:\n    print_figure (print_monkey_head)\nelif choice == 2:\n    print_figure (print_human_head)',
#  '_i12': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\ntotal_inches = (feet * inches_per_foot) + inches # Total inches\ncentimeters = total_inches * centimeters_per_inch\nreturn centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i13': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i14': 'centimeters_per inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  '_i15': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_us_to_centimeters(i_feet,i_inches))',
#  'centimeters_per_inch': 2.54,
#  'inches_per_foot': 12,
#  'height_US_to_centimeters': <function __main__.height_US_to_centimeters(feet, inches)>,
#  'i_feet': 67,
#  'i_inches': 56,
#  '_i16': 'centimeters_per_inch =  2.54\ninches_per_foot = 12\n\ndef height_US_to_centimeters(feet, inches):\n    """ Converts a height in feet/ inches to centimeters."""\n    total_inches = (feet * inches_per_foot) + inches # Total inches\n    centimeters = total_inches * centimeters_per_inch\n    return centimeters\n\ni_feet = int(input(\'Enter feet: \'))\ni_inches = int(input( \' Enter inches:\'))\n\nprint( \'Centimeters: \' , height_US_to_centimeters(i_feet,i_inches))',
#  '_i17': "employee_name = = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i18': "employee_name == 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i19': "employee_name = 'N/A'\ndef get_name():\n\n    name = input( ' Enter employee name: ' )\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  'employee_name': 'kaiwalya pande',
#  'get_name': <function __main__.get_name()>,
#  '_i20': "employee_name = 'N/A'\ndef get_name():\n    global employee_name\n    name = input( 'Enter employee name:')\n    employee_name = name\nget_name ( )\nprint( ' Employee name: ' , employee_name)",
#  '_i21': 'daily_cals = 230 # Daily calories\nsoda_cals = 200\n\ndef drink_soda(cals_left):\n    return cals_left - soda_cals\ndaily_cals = drink_soda(daily_cals)\nprint(daily_cals)',
#  'daily_cals': 30,
#  'soda_cals': 200,
#  'drink_soda': <function __main__.drink_soda(cals_left)>,
#  '_i22': "def avg(a, b):\ntmp = (a+b)/2.O\nreturn tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i23': "def avg(a, b):\n    tmp = (a+b)/2.O\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i24': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'avg': <function __main__.avg(a, b)>,
#  'b': 10,
#  '_i25': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na=5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  'a': 5,
#  'tmp': 15,
#  '_i26': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n# Creates tmp in Local namespace\n+ b # Creates tmp in global namespace\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i27': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i28': "def avg(a, b):\n    tmp = (a+b)/2.0\n    return tmp\na = 5\nb = 10\ntmp = a+b\n\nprint(f'Avg: {avg(a, b): f}' )\nprint(f' Sum: {tmp:f}')",
#  '_i29': 'globals()',
#  '_29': {...},
#  '_i30': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function'my_var)\nglobals()",
#  '_i31': "my_var = 'thi is global'\ndef print_globals_var():\n    print('inside function',my_var)\nglobals()",
#  'my_var': 'thi is global',
#  'print_globals_var': <function __main__.print_globals_var()>,
#  '_31': {...},
#  '_i32': "def avg(a, b):\n    tmp = (a+b)/2.0     # Creates tmp in Locat namespace\n    return tmp\na = 5\nb = 10\ntmp = a + b # Creates tmp in global namespace\n\nprint(f'Avg: {avg(a,b):f}' )\nprint(f'Sum: {tmp:f}')",
#  '_i33': "def print_local_var():\n    my_var_local = 'this is a locals variable'\n    print(locals())\n\nprint_local_var()\nprint('outside function')\nlocals()",
#  'print_local_var': <function __main__.print_local_var()>}

# %% [markdown]
# ### Function arguments

# %%
def birthday(age):
    '''Celebrate birthday'''
    age = age + 1
    return age


timmy_age = 7
print(birthday(timmy_age))
# Out:
# 8

# %% [markdown]
# ### Keyword arguments and default parameter values

# %%
def print_book_description(title, author, publisher, year, version, num_chapters, num_pages):
    print('Title:', title)
    print('Author', author)
    print('Publisher', publisher)
    print('Year', year)
    print('Version', version)
    print(f'Number of chapters: {num_chapters}')
    print(f'Number of pages: {num_pages}')

# %%
# Call the function with arguments
print_book_description('The Lord of Rings', 'J. R. R. Tolkien', 'George Allen & Unwin', 1954, 1.0, 22, 456)
# Out:
# Title: The Lord of Rings
# Author J. R. R. Tolkien
# Publisher George Allen & Unwin
# Year 1954
# Version 1.0
# Number of chapters: 22
# Number of pages: 456

# %%
def print_date(day, month, year, style=0) :
    if style == 0: # American
        print(month, ' / ',day,'/',year)
    elif(style == 1): # European
        print(day, '/' ,month, '/' , year)
    else:
        print( 'Invalid Code')

# %%
print_date(30,7,2012,0)
print_date(30,7, 2012, 1)
print_date(30,7,2012) # style arguments not provivded! Default value of e used.
# Out:
# 7  /  30 / 2012
# 30 / 7 / 2012
# 7  /  30 / 2012

# %%
def append_to_list(value, my_list=[]):
    my_list. append ( value)
    return my_list

numbers= append_to_list (50)     # default List appended with 50
print(numbers)
# Out:
# [50]

# %%
numbers = append_to_list(100)
print(numbers)
# Out:
# [50, 100]

# %%
def print_date(day=1, month=1, year=2000, style=0):
    if style == 0:
        print(f"{day}/{month}/{year}")
    else:
        print(f"{year}-{month}-{day}")
day=1
month=1
year=2000

# %%
print_date(day,month,year,)
# Out:
# 1/1/2000

# %%
print_date(day=28,year=2024)
# Out:
# 28/1/2024

# %%
print_date(style=1)
# Out:
# 2000-1-1

# %%
print_date(year=2020,month=4,day=6)
# Out:
# 6/4/2020

# %% [markdown]
# ### Arbitrary argument lists

# %%
def print _ sandwich (bread, slice, *args):
    print(f'Arbitary arguments are . ' ,
    print(f' {slice} on {bread}' , end='')
    if len(args) > 0:
       print( 'with', end='')
for extra in args:
    print(extra, end='')
print('')

# %%
student_scores = [75, 84, 66, 99, 51, 65]

def get_grade_stats(scores):
    # calculate the arithmetic mean
mean = sum(scores)/len(scores)

# Calculate the standard deviation
tmp = 0
for score in scores:
    tmp += (tmp/len(scores))**2
std_dev = (tmp/1en(scores))**ø.5

# Package and return average, standard deviation in a tuple
return mean, std dev

# Unpack tuple
average, standard_deviation = get_grade_stats(student_scores)

print( 'Average score: ' , average)
print( 'Standard deviation: ' , standard_deviation)
